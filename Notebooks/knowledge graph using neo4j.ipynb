# %%
from neo4j import GraphDatabase

# Set your connection URI and authentication based on your Docker Compose setup
URI = "bolt://localhost:7687"
# AUTH = ("neo4j", "neo4j")

# Create the driver object to connect to Neo4j
# driver = GraphDatabase.driver(URI, auth=AUTH)
driver = GraphDatabase.driver(URI)

# You can add a check to make sure the connection is working
try:
    driver.verify_connectivity()
    print("Connection to Neo4j successful!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection to Neo4j successful!

# %%
import pandas as pd
from neo4j import GraphDatabase

# --- Configuration for Neo4j Connection ---
URI = "bolt://localhost:7687"
# AUTH = ("neo4j", "your_new_password") # Use your actual new password

# --- Step 1: Define functions for each operation type ---

def create_constraints(tx):
    """
    Creates uniqueness constraints in a separate transaction.
    """
    print("Creating uniqueness constraints...")
    tx.run("CREATE CONSTRAINT IF NOT EXISTS FOR (a:Anime) REQUIRE a.anime_id IS UNIQUE")
    tx.run("CREATE CONSTRAINT IF NOT EXISTS FOR (g:Genre) REQUIRE g.name IS UNIQUE")
    tx.run("CREATE CONSTRAINT IF NOT EXISTS FOR (u:User) REQUIRE u.user_id IS UNIQUE")
    print("Constraints created.")
    print("-" * 20)

def ingest_anime_and_genres(tx, anime_df):
    """
    Ingests Anime and Genre nodes and relationships in batches.
    """
    print("Ingesting Anime and Genre nodes and relationships...")

    # Vectorize and batch the anime data
    anime_records = anime_df[['anime_id', 'name', 'type', 'episodes', 'rating']].to_dict('records')
    tx.run("""
    UNWIND $records AS record
    MERGE (a:Anime {anime_id: record.anime_id})
    ON CREATE SET a.title = record.name, a.type = record.type, a.episodes = record.episodes, a.rating = toFloat(record.rating)
    """, records=anime_records)

    # Batch genre data
    genre_data = []
    for _, row in anime_df.iterrows():
        if isinstance(row['genre'], str):
            genres = [genre.strip() for genre in row['genre'].split(',')]
            for genre_name in genres:
                genre_data.append({'anime_id': row['anime_id'], 'genre_name': genre_name})

    tx.run("""
    UNWIND $genre_data AS data
    MERGE (g:Genre {name: data.genre_name})
    WITH g, data
    MATCH (a:Anime {anime_id: data.anime_id})
    MERGE (a)-[:HAS_GENRE]->(g)
    """, genre_data=genre_data)

    print("Anime and Genre ingestion complete.")
    print("-" * 20)

def ingest_ratings_batched(tx, ratings_df, batch_size=2000):
    """
    Ingests User and Rating relationships using batched transactions.
    """
    print("Ingesting User and Rating relationships in batches...")

    # Filter for valid ratings
    valid_ratings = ratings_df[ratings_df['rating'] != -1]
    # Get a list of all unique users
    unique_users = valid_ratings['user_id'].unique()
    print(f"Total number of unique users: {len(unique_users)}")

    # Randomly select 75% of the unique users
    sampled_users = pd.Series(unique_users).sample(frac=0.75)

    # Filter the original DataFrame to keep only the selected users' records
    reduced_rating_df = valid_ratings[valid_ratings['user_id'].isin(sampled_users)]
    
    # Convert DataFrame to a list of dictionaries for efficient processing
    rating_records = reduced_rating_df.to_dict('records')
    
    rating_query = """
    UNWIND $batch AS record
    MERGE (u:User {user_id: record.user_id})
    WITH u, record
    MATCH (a:Anime {anime_id: record.anime_id})
    MERGE (u)-[r:RATED]->(a)
    ON CREATE SET r.score = toInteger(record.rating)
    """

    for i in range(0, len(rating_records), batch_size):
        batch = rating_records[i:i + batch_size]
        tx.run(rating_query, batch=batch)
        print(f"  Ingested batch {i // batch_size + 1} of {len(rating_records) // batch_size + 1}")
    
    print("User and Rating ingestion complete.")
    print("-" * 20)




# --- Main execution block ---
if __name__ == '__main__':
    # Load and preprocess the data
    print("Loading and preprocessing data...")
    anime_df = pd.read_csv('data/anime.csv')
    rating_df = pd.read_csv('data/rating.csv')
    anime_df.dropna(subset=['genre'], inplace=True)
    print("Data loaded successfully.")
    print("-" * 20)

    # Create the Neo4j driver
    driver = GraphDatabase.driver(URI) #, auth=AUTH)

    # Execute all ingestion steps in separate transactions
    with driver.session() as session:
        session.execute_write(create_constraints)
        session.execute_write(ingest_anime_and_genres, anime_df)
        session.execute_write(ingest_ratings_batched, rating_df)

    # Close the driver connection
    driver.close()
    print("Driver connection closed.")
# Out:
# Loading and preprocessing data...
# Data loaded successfully.
# --------------------
# Creating uniqueness constraints...
# Constraints created.
# --------------------
# Ingesting Anime and Genre nodes and relationships...
# Anime and Genre ingestion complete.
# --------------------
# Ingesting User and Rating relationships in batches...
# Total number of unique users: 69600
#   Ingested batch 1 of 2387
#   Ingested batch 2 of 2387
#   Ingested batch 3 of 2387
#   Ingested batch 4 of 2387
#   Ingested batch 5 of 2387
#   Ingested batch 6 of 2387
#   Ingested batch 7 of 2387
#   Ingested batch 8 of 2387
#   Ingested batch 9 of 2387
#   Ingested batch 10 of 2387
#   Ingested batch 11 of 2387
#   Ingested batch 12 of 2387
#   Ingested batch 13 of 2387
#   Ingested batch 14 of 2387
#   Ingested batch 15 of 2387
#   Ingested batch 16 of 2387
#   Ingested batch 17 of 2387
#   Ingested batch 18 of 2387
#   Ingested batch 19 of 2387
#   Ingested batch 20 of 2387
#   Ingested batch 21 of 2387
#   Ingested batch 22 of 2387
#   Ingested batch 23 of 2387
#   Ingested batch 24 of 2387
#   Ingested batch 25 of 2387
#   Ingested batch 26 of 2387
#   Ingested batch 27 of 2387
#   Ingested batch 28 of 2387
#   Ingested batch 29 of 2387
#   Ingested batch 30 of 2387
#   Ingested batch 31 of 2387
#   Ingested batch 32 of 2387
#   Ingested batch 33 of 2387
#   Ingested batch 34 of 2387
#   Ingested batch 35 of 2387
#   Ingested batch 36 of 2387
#   Ingested batch 37 of 2387
#   Ingested batch 38 of 2387
#   Ingested batch 39 of 2387
#   Ingested batch 40 of 2387
#   Ingested batch 41 of 2387
#   Ingested batch 42 of 2387
#   Ingested batch 43 of 2387
#   Ingested batch 44 of 2387
#   Ingested batch 45 of 2387
#   Ingested batch 46 of 2387
#   Ingested batch 47 of 2387
#   Ingested batch 48 of 2387
#   Ingested batch 49 of 2387
#   Ingested batch 50 of 2387
#   Ingested batch 51 of 2387
#   Ingested batch 52 of 2387
#   Ingested batch 53 of 2387
#   Ingested batch 54 of 2387
#   Ingested batch 55 of 2387
#   Ingested batch 56 of 2387
#   Ingested batch 57 of 2387
#   Ingested batch 58 of 2387
#   Ingested batch 59 of 2387
#   Ingested batch 60 of 2387
#   Ingested batch 61 of 2387
#   Ingested batch 62 of 2387
#   Ingested batch 63 of 2387
#   Ingested batch 64 of 2387
#   Ingested batch 65 of 2387
#   Ingested batch 66 of 2387
#   Ingested batch 67 of 2387
#   Ingested batch 68 of 2387
#   Ingested batch 69 of 2387
#   Ingested batch 70 of 2387
#   Ingested batch 71 of 2387
#   Ingested batch 72 of 2387
#   Ingested batch 73 of 2387
#   Ingested batch 74 of 2387
#   Ingested batch 75 of 2387
#   Ingested batch 76 of 2387
#   Ingested batch 77 of 2387
#   Ingested batch 78 of 2387
#   Ingested batch 79 of 2387
#   Ingested batch 80 of 2387
#   Ingested batch 81 of 2387
#   Ingested batch 82 of 2387
#   Ingested batch 83 of 2387
#   Ingested batch 84 of 2387
#   Ingested batch 85 of 2387
#   Ingested batch 86 of 2387
#   Ingested batch 87 of 2387
#   Ingested batch 88 of 2387
#   Ingested batch 89 of 2387
#   Ingested batch 90 of 2387
#   Ingested batch 91 of 2387
#   Ingested batch 92 of 2387
#   Ingested batch 93 of 2387
#   Ingested batch 94 of 2387
#   Ingested batch 95 of 2387
#   Ingested batch 96 of 2387
#   Ingested batch 97 of 2387
#   Ingested batch 98 of 2387
#   Ingested batch 99 of 2387
#   Ingested batch 100 of 2387
#   Ingested batch 101 of 2387
#   Ingested batch 102 of 2387
#   Ingested batch 103 of 2387
#   Ingested batch 104 of 2387
#   Ingested batch 105 of 2387
#   Ingested batch 106 of 2387
#   Ingested batch 107 of 2387
#   Ingested batch 108 of 2387
#   Ingested batch 109 of 2387
#   Ingested batch 110 of 2387
#   Ingested batch 111 of 2387
#   Ingested batch 112 of 2387
#   Ingested batch 113 of 2387
#   Ingested batch 114 of 2387
#   Ingested batch 115 of 2387
#   Ingested batch 116 of 2387
#   Ingested batch 117 of 2387
#   Ingested batch 118 of 2387
#   Ingested batch 119 of 2387
#   Ingested batch 120 of 2387
#   Ingested batch 121 of 2387
#   Ingested batch 122 of 2387
#   Ingested batch 123 of 2387
#   Ingested batch 124 of 2387
#   Ingested batch 125 of 2387
#   Ingested batch 126 of 2387
#   Ingested batch 127 of 2387
#   Ingested batch 128 of 2387
#   Ingested batch 129 of 2387
#   Ingested batch 130 of 2387
#   Ingested batch 131 of 2387
#   Ingested batch 132 of 2387
#   Ingested batch 133 of 2387
#   Ingested batch 134 of 2387
#   Ingested batch 135 of 2387
#   Ingested batch 136 of 2387
#   Ingested batch 137 of 2387
#   Ingested batch 138 of 2387
#   Ingested batch 139 of 2387
#   Ingested batch 140 of 2387
#   Ingested batch 141 of 2387
#   Ingested batch 142 of 2387
#   Ingested batch 143 of 2387
#   Ingested batch 144 of 2387
#   Ingested batch 145 of 2387
#   Ingested batch 146 of 2387
#   Ingested batch 147 of 2387
#   Ingested batch 148 of 2387
#   Ingested batch 149 of 2387
#   Ingested batch 150 of 2387
#   Ingested batch 151 of 2387
#   Ingested batch 152 of 2387
#   Ingested batch 153 of 2387
#   Ingested batch 154 of 2387
#   Ingested batch 155 of 2387
#   Ingested batch 156 of 2387
#   Ingested batch 157 of 2387
#   Ingested batch 158 of 2387
#   Ingested batch 159 of 2387
#   Ingested batch 160 of 2387
#   Ingested batch 161 of 2387
#   Ingested batch 162 of 2387
#   Ingested batch 163 of 2387
#   Ingested batch 164 of 2387
#   Ingested batch 165 of 2387
#   Ingested batch 166 of 2387
#   Ingested batch 167 of 2387
#   Ingested batch 168 of 2387
#   Ingested batch 169 of 2387
#   Ingested batch 170 of 2387
#   Ingested batch 171 of 2387
#   Ingested batch 172 of 2387
#   Ingested batch 173 of 2387
#   Ingested batch 174 of 2387
#   Ingested batch 175 of 2387
#   Ingested batch 176 of 2387
#   Ingested batch 177 of 2387
#   Ingested batch 178 of 2387
#   Ingested batch 179 of 2387
#   Ingested batch 180 of 2387
#   Ingested batch 181 of 2387
#   Ingested batch 182 of 2387
#   Ingested batch 183 of 2387
#   Ingested batch 184 of 2387
#   Ingested batch 185 of 2387
#   Ingested batch 186 of 2387
#   Ingested batch 187 of 2387
#   Ingested batch 188 of 2387
#   Ingested batch 189 of 2387
#   Ingested batch 190 of 2387
#   Ingested batch 191 of 2387
#   Ingested batch 192 of 2387
#   Ingested batch 193 of 2387
#   Ingested batch 194 of 2387
#   Ingested batch 195 of 2387
#   Ingested batch 196 of 2387
#   Ingested batch 197 of 2387
#   Ingested batch 198 of 2387
#   Ingested batch 199 of 2387
#   Ingested batch 200 of 2387
#   Ingested batch 201 of 2387
#   Ingested batch 202 of 2387
#   Ingested batch 203 of 2387
#   Ingested batch 204 of 2387
#   Ingested batch 205 of 2387
#   Ingested batch 206 of 2387
#   Ingested batch 207 of 2387
#   Ingested batch 208 of 2387
#   Ingested batch 209 of 2387
#   Ingested batch 210 of 2387
#   Ingested batch 211 of 2387
#   Ingested batch 212 of 2387
#   Ingested batch 213 of 2387
#   Ingested batch 214 of 2387
#   Ingested batch 215 of 2387
#   Ingested batch 216 of 2387
#   Ingested batch 217 of 2387
#   Ingested batch 218 of 2387
#   Ingested batch 219 of 2387
#   Ingested batch 220 of 2387
#   Ingested batch 221 of 2387
#   Ingested batch 222 of 2387
#   Ingested batch 223 of 2387
#   Ingested batch 224 of 2387
#   Ingested batch 225 of 2387
#   Ingested batch 226 of 2387
#   Ingested batch 227 of 2387
#   Ingested batch 228 of 2387
#   Ingested batch 229 of 2387
#   Ingested batch 230 of 2387
#   Ingested batch 231 of 2387
#   Ingested batch 232 of 2387
#   Ingested batch 233 of 2387
#   Ingested batch 234 of 2387
#   Ingested batch 235 of 2387
#   Ingested batch 236 of 2387
#   Ingested batch 237 of 2387
#   Ingested batch 238 of 2387
#   Ingested batch 239 of 2387
#   Ingested batch 240 of 2387
#   Ingested batch 241 of 2387
#   Ingested batch 242 of 2387
#   Ingested batch 243 of 2387
#   Ingested batch 244 of 2387
#   Ingested batch 245 of 2387
#   Ingested batch 246 of 2387
#   Ingested batch 247 of 2387
#   Ingested batch 248 of 2387
#   Ingested batch 249 of 2387
#   Ingested batch 250 of 2387
#   Ingested batch 251 of 2387
#   Ingested batch 252 of 2387
#   Ingested batch 253 of 2387
#   Ingested batch 254 of 2387
#   Ingested batch 255 of 2387
#   Ingested batch 256 of 2387
#   Ingested batch 257 of 2387
#   Ingested batch 258 of 2387
#   Ingested batch 259 of 2387
#   Ingested batch 260 of 2387
#   Ingested batch 261 of 2387
#   Ingested batch 262 of 2387
#   Ingested batch 263 of 2387
#   Ingested batch 264 of 2387
#   Ingested batch 265 of 2387
#   Ingested batch 266 of 2387
#   Ingested batch 267 of 2387
#   Ingested batch 268 of 2387
#   Ingested batch 269 of 2387
#   Ingested batch 270 of 2387
#   Ingested batch 271 of 2387
#   Ingested batch 272 of 2387
#   Ingested batch 273 of 2387
#   Ingested batch 274 of 2387
#   Ingested batch 275 of 2387
#   Ingested batch 276 of 2387
#   Ingested batch 277 of 2387
#   Ingested batch 278 of 2387
#   Ingested batch 279 of 2387
#   Ingested batch 280 of 2387
#   Ingested batch 281 of 2387
#   Ingested batch 282 of 2387
#   Ingested batch 283 of 2387
#   Ingested batch 284 of 2387
#   Ingested batch 285 of 2387
#   Ingested batch 286 of 2387
#   Ingested batch 287 of 2387
#   Ingested batch 288 of 2387
#   Ingested batch 289 of 2387
#   Ingested batch 290 of 2387
#   Ingested batch 291 of 2387
#   Ingested batch 292 of 2387
#   Ingested batch 293 of 2387
#   Ingested batch 294 of 2387
#   Ingested batch 295 of 2387
#   Ingested batch 296 of 2387
#   Ingested batch 297 of 2387
#   Ingested batch 298 of 2387
#   Ingested batch 299 of 2387
#   Ingested batch 300 of 2387
#   Ingested batch 301 of 2387
#   Ingested batch 302 of 2387
#   Ingested batch 303 of 2387
#   Ingested batch 304 of 2387
#   Ingested batch 305 of 2387
#   Ingested batch 306 of 2387
#   Ingested batch 307 of 2387
#   Ingested batch 308 of 2387
#   Ingested batch 309 of 2387
#   Ingested batch 310 of 2387
#   Ingested batch 311 of 2387
#   Ingested batch 312 of 2387
#   Ingested batch 313 of 2387
#   Ingested batch 314 of 2387
#   Ingested batch 315 of 2387
#   Ingested batch 316 of 2387
#   Ingested batch 317 of 2387
#   Ingested batch 318 of 2387
#   Ingested batch 319 of 2387
#   Ingested batch 320 of 2387
#   Ingested batch 321 of 2387
#   Ingested batch 322 of 2387
#   Ingested batch 323 of 2387
#   Ingested batch 324 of 2387
#   Ingested batch 325 of 2387
#   Ingested batch 326 of 2387
#   Ingested batch 327 of 2387
#   Ingested batch 328 of 2387
#   Ingested batch 329 of 2387
#   Ingested batch 330 of 2387
#   Ingested batch 331 of 2387
#   Ingested batch 332 of 2387
#   Ingested batch 333 of 2387
#   Ingested batch 334 of 2387
#   Ingested batch 335 of 2387
#   Ingested batch 336 of 2387
#   Ingested batch 337 of 2387
#   Ingested batch 338 of 2387
#   Ingested batch 339 of 2387
#   Ingested batch 340 of 2387
#   Ingested batch 341 of 2387
#   Ingested batch 342 of 2387
#   Ingested batch 343 of 2387
#   Ingested batch 344 of 2387
#   Ingested batch 345 of 2387
#   Ingested batch 346 of 2387
#   Ingested batch 347 of 2387
#   Ingested batch 348 of 2387
#   Ingested batch 349 of 2387
#   Ingested batch 350 of 2387
#   Ingested batch 351 of 2387
#   Ingested batch 352 of 2387
#   Ingested batch 353 of 2387
#   Ingested batch 354 of 2387
#   Ingested batch 355 of 2387
#   Ingested batch 356 of 2387
#   Ingested batch 357 of 2387
#   Ingested batch 358 of 2387
#   Ingested batch 359 of 2387
#   Ingested batch 360 of 2387
#   Ingested batch 361 of 2387
#   Ingested batch 362 of 2387
#   Ingested batch 363 of 2387
#   Ingested batch 364 of 2387
#   Ingested batch 365 of 2387
#   Ingested batch 366 of 2387
#   Ingested batch 367 of 2387
#   Ingested batch 368 of 2387
#   Ingested batch 369 of 2387
#   Ingested batch 370 of 2387
#   Ingested batch 371 of 2387
#   Ingested batch 372 of 2387
#   Ingested batch 373 of 2387
#   Ingested batch 374 of 2387
#   Ingested batch 375 of 2387
#   Ingested batch 376 of 2387
#   Ingested batch 377 of 2387
#   Ingested batch 378 of 2387
#   Ingested batch 379 of 2387
#   Ingested batch 380 of 2387
#   Ingested batch 381 of 2387
#   Ingested batch 382 of 2387
#   Ingested batch 383 of 2387
#   Ingested batch 384 of 2387
#   Ingested batch 385 of 2387
#   Ingested batch 386 of 2387
#   Ingested batch 387 of 2387
#   Ingested batch 388 of 2387
#   Ingested batch 389 of 2387
#   Ingested batch 390 of 2387
#   Ingested batch 391 of 2387
#   Ingested batch 392 of 2387
#   Ingested batch 393 of 2387
#   Ingested batch 394 of 2387
#   Ingested batch 395 of 2387
#   Ingested batch 396 of 2387
#   Ingested batch 397 of 2387
#   Ingested batch 398 of 2387
#   Ingested batch 399 of 2387
#   Ingested batch 400 of 2387
#   Ingested batch 401 of 2387
#   Ingested batch 402 of 2387
#   Ingested batch 403 of 2387
#   Ingested batch 404 of 2387
#   Ingested batch 405 of 2387
#   Ingested batch 406 of 2387
#   Ingested batch 407 of 2387
#   Ingested batch 408 of 2387
#   Ingested batch 409 of 2387
#   Ingested batch 410 of 2387
#   Ingested batch 411 of 2387
#   Ingested batch 412 of 2387
#   Ingested batch 413 of 2387
#   Ingested batch 414 of 2387
#   Ingested batch 415 of 2387
#   Ingested batch 416 of 2387
#   Ingested batch 417 of 2387
#   Ingested batch 418 of 2387
#   Ingested batch 419 of 2387
#   Ingested batch 420 of 2387
#   Ingested batch 421 of 2387
#   Ingested batch 422 of 2387
#   Ingested batch 423 of 2387
#   Ingested batch 424 of 2387
#   Ingested batch 425 of 2387
#   Ingested batch 426 of 2387
#   Ingested batch 427 of 2387
#   Ingested batch 428 of 2387
#   Ingested batch 429 of 2387
#   Ingested batch 430 of 2387
#   Ingested batch 431 of 2387
#   Ingested batch 432 of 2387
#   Ingested batch 433 of 2387
#   Ingested batch 434 of 2387
#   Ingested batch 435 of 2387
#   Ingested batch 436 of 2387
#   Ingested batch 437 of 2387
#   Ingested batch 438 of 2387
#   Ingested batch 439 of 2387
#   Ingested batch 440 of 2387
#   Ingested batch 441 of 2387
#   Ingested batch 442 of 2387
#   Ingested batch 443 of 2387
#   Ingested batch 444 of 2387
#   Ingested batch 445 of 2387
#   Ingested batch 446 of 2387
#   Ingested batch 447 of 2387
#   Ingested batch 448 of 2387
#   Ingested batch 449 of 2387
#   Ingested batch 450 of 2387
#   Ingested batch 451 of 2387
#   Ingested batch 452 of 2387
#   Ingested batch 453 of 2387
#   Ingested batch 454 of 2387
#   Ingested batch 455 of 2387
#   Ingested batch 456 of 2387
#   Ingested batch 457 of 2387
#   Ingested batch 458 of 2387
#   Ingested batch 459 of 2387
#   Ingested batch 460 of 2387
#   Ingested batch 461 of 2387
#   Ingested batch 462 of 2387
#   Ingested batch 463 of 2387
#   Ingested batch 464 of 2387
#   Ingested batch 465 of 2387
#   Ingested batch 466 of 2387
#   Ingested batch 467 of 2387
#   Ingested batch 468 of 2387
#   Ingested batch 469 of 2387
#   Ingested batch 470 of 2387
#   Ingested batch 471 of 2387
#   Ingested batch 472 of 2387
#   Ingested batch 473 of 2387
#   Ingested batch 474 of 2387
#   Ingested batch 475 of 2387
#   Ingested batch 476 of 2387
#   Ingested batch 477 of 2387
#   Ingested batch 478 of 2387
#   Ingested batch 479 of 2387
#   Ingested batch 480 of 2387
#   Ingested batch 481 of 2387
#   Ingested batch 482 of 2387
#   Ingested batch 483 of 2387
#   Ingested batch 484 of 2387
#   Ingested batch 485 of 2387
#   Ingested batch 486 of 2387
#   Ingested batch 487 of 2387
#   Ingested batch 488 of 2387
#   Ingested batch 489 of 2387
#   Ingested batch 490 of 2387
#   Ingested batch 491 of 2387
#   Ingested batch 492 of 2387
#   Ingested batch 493 of 2387
#   Ingested batch 494 of 2387
#   Ingested batch 495 of 2387
#   Ingested batch 496 of 2387
#   Ingested batch 497 of 2387
#   Ingested batch 498 of 2387
#   Ingested batch 499 of 2387
#   Ingested batch 500 of 2387
#   Ingested batch 501 of 2387
#   Ingested batch 502 of 2387
#   Ingested batch 503 of 2387
#   Ingested batch 504 of 2387
#   Ingested batch 505 of 2387
#   Ingested batch 506 of 2387
#   Ingested batch 507 of 2387
#   Ingested batch 508 of 2387
#   Ingested batch 509 of 2387
#   Ingested batch 510 of 2387
#   Ingested batch 511 of 2387
#   Ingested batch 512 of 2387
#   Ingested batch 513 of 2387
#   Ingested batch 514 of 2387
#   Ingested batch 515 of 2387
#   Ingested batch 516 of 2387
#   Ingested batch 517 of 2387
#   Ingested batch 518 of 2387
#   Ingested batch 519 of 2387
#   Ingested batch 520 of 2387
#   Ingested batch 521 of 2387
#   Ingested batch 522 of 2387
#   Ingested batch 523 of 2387
#   Ingested batch 524 of 2387
#   Ingested batch 525 of 2387
#   Ingested batch 526 of 2387
#   Ingested batch 527 of 2387
#   Ingested batch 528 of 2387
#   Ingested batch 529 of 2387
#   Ingested batch 530 of 2387
#   Ingested batch 531 of 2387
#   Ingested batch 532 of 2387
#   Ingested batch 533 of 2387
#   Ingested batch 534 of 2387
#   Ingested batch 535 of 2387
#   Ingested batch 536 of 2387
#   Ingested batch 537 of 2387
#   Ingested batch 538 of 2387
#   Ingested batch 539 of 2387
#   Ingested batch 540 of 2387
#   Ingested batch 541 of 2387
#   Ingested batch 542 of 2387
#   Ingested batch 543 of 2387
#   Ingested batch 544 of 2387
#   Ingested batch 545 of 2387
#   Ingested batch 546 of 2387
#   Ingested batch 547 of 2387
#   Ingested batch 548 of 2387
#   Ingested batch 549 of 2387
#   Ingested batch 550 of 2387
#   Ingested batch 551 of 2387
#   Ingested batch 552 of 2387
#   Ingested batch 553 of 2387
#   Ingested batch 554 of 2387
#   Ingested batch 555 of 2387
#   Ingested batch 556 of 2387
#   Ingested batch 557 of 2387
#   Ingested batch 558 of 2387
#   Ingested batch 559 of 2387
#   Ingested batch 560 of 2387
#   Ingested batch 561 of 2387
#   Ingested batch 562 of 2387
#   Ingested batch 563 of 2387
#   Ingested batch 564 of 2387
#   Ingested batch 565 of 2387
#   Ingested batch 566 of 2387
#   Ingested batch 567 of 2387
#   Ingested batch 568 of 2387
#   Ingested batch 569 of 2387
#   Ingested batch 570 of 2387
#   Ingested batch 571 of 2387
#   Ingested batch 572 of 2387
#   Ingested batch 573 of 2387
#   Ingested batch 574 of 2387
#   Ingested batch 575 of 2387
#   Ingested batch 576 of 2387
#   Ingested batch 577 of 2387
#   Ingested batch 578 of 2387
#   Ingested batch 579 of 2387
#   Ingested batch 580 of 2387
#   Ingested batch 581 of 2387
#   Ingested batch 582 of 2387
#   Ingested batch 583 of 2387
#   Ingested batch 584 of 2387
#   Ingested batch 585 of 2387
#   Ingested batch 586 of 2387
#   Ingested batch 587 of 2387
#   Ingested batch 588 of 2387
#   Ingested batch 589 of 2387
#   Ingested batch 590 of 2387
#   Ingested batch 591 of 2387
#   Ingested batch 592 of 2387
#   Ingested batch 593 of 2387
#   Ingested batch 594 of 2387
#   Ingested batch 595 of 2387
#   Ingested batch 596 of 2387
#   Ingested batch 597 of 2387
#   Ingested batch 598 of 2387
#   Ingested batch 599 of 2387
#   Ingested batch 600 of 2387
#   Ingested batch 601 of 2387
#   Ingested batch 602 of 2387
#   Ingested batch 603 of 2387
#   Ingested batch 604 of 2387
#   Ingested batch 605 of 2387
#   Ingested batch 606 of 2387
#   Ingested batch 607 of 2387
#   Ingested batch 608 of 2387
#   Ingested batch 609 of 2387
#   Ingested batch 610 of 2387
#   Ingested batch 611 of 2387
#   Ingested batch 612 of 2387
#   Ingested batch 613 of 2387
#   Ingested batch 614 of 2387
#   Ingested batch 615 of 2387
#   Ingested batch 616 of 2387
#   Ingested batch 617 of 2387
#   Ingested batch 618 of 2387
#   Ingested batch 619 of 2387
#   Ingested batch 620 of 2387
#   Ingested batch 621 of 2387
#   Ingested batch 622 of 2387
#   Ingested batch 623 of 2387
#   Ingested batch 624 of 2387
#   Ingested batch 625 of 2387
#   Ingested batch 626 of 2387
#   Ingested batch 627 of 2387
#   Ingested batch 628 of 2387
#   Ingested batch 629 of 2387
#   Ingested batch 630 of 2387
#   Ingested batch 631 of 2387
#   Ingested batch 632 of 2387
#   Ingested batch 633 of 2387
#   Ingested batch 634 of 2387
#   Ingested batch 635 of 2387
#   Ingested batch 636 of 2387
#   Ingested batch 637 of 2387
#   Ingested batch 638 of 2387
#   Ingested batch 639 of 2387
#   Ingested batch 640 of 2387
#   Ingested batch 641 of 2387
#   Ingested batch 642 of 2387
#   Ingested batch 643 of 2387
#   Ingested batch 644 of 2387
#   Ingested batch 645 of 2387
#   Ingested batch 646 of 2387
#   Ingested batch 647 of 2387
#   Ingested batch 648 of 2387
#   Ingested batch 649 of 2387
#   Ingested batch 650 of 2387
#   Ingested batch 651 of 2387
#   Ingested batch 652 of 2387
#   Ingested batch 653 of 2387
#   Ingested batch 654 of 2387
#   Ingested batch 655 of 2387
#   Ingested batch 656 of 2387
#   Ingested batch 657 of 2387
#   Ingested batch 658 of 2387
#   Ingested batch 659 of 2387
#   Ingested batch 660 of 2387
#   Ingested batch 661 of 2387
#   Ingested batch 662 of 2387
#   Ingested batch 663 of 2387
#   Ingested batch 664 of 2387
#   Ingested batch 665 of 2387
#   Ingested batch 666 of 2387
#   Ingested batch 667 of 2387
#   Ingested batch 668 of 2387
#   Ingested batch 669 of 2387
#   Ingested batch 670 of 2387
#   Ingested batch 671 of 2387
#   Ingested batch 672 of 2387
#   Ingested batch 673 of 2387
#   Ingested batch 674 of 2387
#   Ingested batch 675 of 2387
#   Ingested batch 676 of 2387
#   Ingested batch 677 of 2387
#   Ingested batch 678 of 2387
#   Ingested batch 679 of 2387
#   Ingested batch 680 of 2387
#   Ingested batch 681 of 2387
#   Ingested batch 682 of 2387
#   Ingested batch 683 of 2387
#   Ingested batch 684 of 2387
#   Ingested batch 685 of 2387
#   Ingested batch 686 of 2387
#   Ingested batch 687 of 2387
#   Ingested batch 688 of 2387
#   Ingested batch 689 of 2387
#   Ingested batch 690 of 2387
#   Ingested batch 691 of 2387
#   Ingested batch 692 of 2387
#   Ingested batch 693 of 2387
#   Ingested batch 694 of 2387
#   Ingested batch 695 of 2387
#   Ingested batch 696 of 2387
#   Ingested batch 697 of 2387
#   Ingested batch 698 of 2387
#   Ingested batch 699 of 2387
#   Ingested batch 700 of 2387
#   Ingested batch 701 of 2387
#   Ingested batch 702 of 2387
#   Ingested batch 703 of 2387
#   Ingested batch 704 of 2387
#   Ingested batch 705 of 2387
#   Ingested batch 706 of 2387
#   Ingested batch 707 of 2387
#   Ingested batch 708 of 2387
#   Ingested batch 709 of 2387
#   Ingested batch 710 of 2387
#   Ingested batch 711 of 2387
#   Ingested batch 712 of 2387
#   Ingested batch 713 of 2387
#   Ingested batch 714 of 2387
#   Ingested batch 715 of 2387
#   Ingested batch 716 of 2387
#   Ingested batch 717 of 2387
#   Ingested batch 718 of 2387
#   Ingested batch 719 of 2387
#   Ingested batch 720 of 2387
#   Ingested batch 721 of 2387
#   Ingested batch 722 of 2387
#   Ingested batch 723 of 2387
#   Ingested batch 724 of 2387
#   Ingested batch 725 of 2387
#   Ingested batch 726 of 2387
#   Ingested batch 727 of 2387
#   Ingested batch 728 of 2387
#   Ingested batch 729 of 2387
#   Ingested batch 730 of 2387
#   Ingested batch 731 of 2387
#   Ingested batch 732 of 2387
#   Ingested batch 733 of 2387
#   Ingested batch 734 of 2387
#   Ingested batch 735 of 2387
#   Ingested batch 736 of 2387
#   Ingested batch 737 of 2387
#   Ingested batch 738 of 2387
#   Ingested batch 739 of 2387
#   Ingested batch 740 of 2387
#   Ingested batch 741 of 2387
#   Ingested batch 742 of 2387
#   Ingested batch 743 of 2387
#   Ingested batch 744 of 2387
#   Ingested batch 745 of 2387
#   Ingested batch 746 of 2387
#   Ingested batch 747 of 2387
#   Ingested batch 748 of 2387
#   Ingested batch 749 of 2387
#   Ingested batch 750 of 2387
#   Ingested batch 751 of 2387
#   Ingested batch 752 of 2387
#   Ingested batch 753 of 2387
#   Ingested batch 754 of 2387
#   Ingested batch 755 of 2387
#   Ingested batch 756 of 2387
#   Ingested batch 757 of 2387
#   Ingested batch 758 of 2387
#   Ingested batch 759 of 2387
#   Ingested batch 760 of 2387
#   Ingested batch 761 of 2387
#   Ingested batch 762 of 2387
#   Ingested batch 763 of 2387
#   Ingested batch 764 of 2387
#   Ingested batch 765 of 2387
#   Ingested batch 766 of 2387
#   Ingested batch 767 of 2387
#   Ingested batch 768 of 2387
#   Ingested batch 769 of 2387
#   Ingested batch 770 of 2387
#   Ingested batch 771 of 2387
#   Ingested batch 772 of 2387
#   Ingested batch 773 of 2387
#   Ingested batch 774 of 2387
#   Ingested batch 775 of 2387
#   Ingested batch 776 of 2387
#   Ingested batch 777 of 2387
#   Ingested batch 778 of 2387
#   Ingested batch 779 of 2387
#   Ingested batch 780 of 2387
#   Ingested batch 781 of 2387
#   Ingested batch 782 of 2387
#   Ingested batch 783 of 2387
#   Ingested batch 784 of 2387
#   Ingested batch 785 of 2387
#   Ingested batch 786 of 2387
#   Ingested batch 787 of 2387
#   Ingested batch 788 of 2387
#   Ingested batch 789 of 2387
#   Ingested batch 790 of 2387
#   Ingested batch 791 of 2387
#   Ingested batch 792 of 2387
#   Ingested batch 793 of 2387
#   Ingested batch 794 of 2387
#   Ingested batch 795 of 2387
#   Ingested batch 796 of 2387
#   Ingested batch 797 of 2387
#   Ingested batch 798 of 2387
#   Ingested batch 799 of 2387
#   Ingested batch 800 of 2387
#   Ingested batch 801 of 2387
#   Ingested batch 802 of 2387
#   Ingested batch 803 of 2387
#   Ingested batch 804 of 2387
#   Ingested batch 805 of 2387
#   Ingested batch 806 of 2387
#   Ingested batch 807 of 2387
#   Ingested batch 808 of 2387
#   Ingested batch 809 of 2387
#   Ingested batch 810 of 2387
#   Ingested batch 811 of 2387
#   Ingested batch 812 of 2387
#   Ingested batch 813 of 2387
#   Ingested batch 814 of 2387
#   Ingested batch 815 of 2387
#   Ingested batch 816 of 2387
#   Ingested batch 817 of 2387
#   Ingested batch 818 of 2387
#   Ingested batch 819 of 2387
#   Ingested batch 820 of 2387
#   Ingested batch 821 of 2387
#   Ingested batch 822 of 2387
#   Ingested batch 823 of 2387
#   Ingested batch 824 of 2387
#   Ingested batch 825 of 2387
#   Ingested batch 826 of 2387
#   Ingested batch 827 of 2387
#   Ingested batch 828 of 2387
#   Ingested batch 829 of 2387
#   Ingested batch 830 of 2387
#   Ingested batch 831 of 2387
#   Ingested batch 832 of 2387
#   Ingested batch 833 of 2387
#   Ingested batch 834 of 2387
#   Ingested batch 835 of 2387
#   Ingested batch 836 of 2387
#   Ingested batch 837 of 2387
#   Ingested batch 838 of 2387
#   Ingested batch 839 of 2387
#   Ingested batch 840 of 2387
#   Ingested batch 841 of 2387
#   Ingested batch 842 of 2387
#   Ingested batch 843 of 2387
#   Ingested batch 844 of 2387
#   Ingested batch 845 of 2387
#   Ingested batch 846 of 2387
#   Ingested batch 847 of 2387
#   Ingested batch 848 of 2387
#   Ingested batch 849 of 2387
#   Ingested batch 850 of 2387
#   Ingested batch 851 of 2387
#   Ingested batch 852 of 2387
#   Ingested batch 853 of 2387
#   Ingested batch 854 of 2387
#   Ingested batch 855 of 2387
#   Ingested batch 856 of 2387
#   Ingested batch 857 of 2387
#   Ingested batch 858 of 2387
#   Ingested batch 859 of 2387
#   Ingested batch 860 of 2387
#   Ingested batch 861 of 2387
#   Ingested batch 862 of 2387
#   Ingested batch 863 of 2387
#   Ingested batch 864 of 2387
#   Ingested batch 865 of 2387
#   Ingested batch 866 of 2387
#   Ingested batch 867 of 2387
#   Ingested batch 868 of 2387
#   Ingested batch 869 of 2387
#   Ingested batch 870 of 2387
#   Ingested batch 871 of 2387
#   Ingested batch 872 of 2387
#   Ingested batch 873 of 2387
#   Ingested batch 874 of 2387
#   Ingested batch 875 of 2387
#   Ingested batch 876 of 2387
#   Ingested batch 877 of 2387
#   Ingested batch 878 of 2387
#   Ingested batch 879 of 2387
#   Ingested batch 880 of 2387
#   Ingested batch 881 of 2387
#   Ingested batch 882 of 2387
#   Ingested batch 883 of 2387
#   Ingested batch 884 of 2387
#   Ingested batch 885 of 2387
#   Ingested batch 886 of 2387
#   Ingested batch 887 of 2387
#   Ingested batch 888 of 2387
#   Ingested batch 889 of 2387
#   Ingested batch 890 of 2387
#   Ingested batch 891 of 2387
#   Ingested batch 892 of 2387
#   Ingested batch 893 of 2387
#   Ingested batch 894 of 2387
#   Ingested batch 895 of 2387
#   Ingested batch 896 of 2387
#   Ingested batch 897 of 2387
#   Ingested batch 898 of 2387
#   Ingested batch 899 of 2387
#   Ingested batch 900 of 2387
#   Ingested batch 901 of 2387
#   Ingested batch 902 of 2387
#   Ingested batch 903 of 2387
#   Ingested batch 904 of 2387
#   Ingested batch 905 of 2387
#   Ingested batch 906 of 2387
#   Ingested batch 907 of 2387
#   Ingested batch 908 of 2387
#   Ingested batch 909 of 2387
#   Ingested batch 910 of 2387
#   Ingested batch 911 of 2387
#   Ingested batch 912 of 2387
#   Ingested batch 913 of 2387
#   Ingested batch 914 of 2387
#   Ingested batch 915 of 2387
#   Ingested batch 916 of 2387
#   Ingested batch 917 of 2387
#   Ingested batch 918 of 2387
#   Ingested batch 919 of 2387
#   Ingested batch 920 of 2387
#   Ingested batch 921 of 2387
#   Ingested batch 922 of 2387
#   Ingested batch 923 of 2387
#   Ingested batch 924 of 2387
#   Ingested batch 925 of 2387
#   Ingested batch 926 of 2387
#   Ingested batch 927 of 2387
#   Ingested batch 928 of 2387
#   Ingested batch 929 of 2387
#   Ingested batch 930 of 2387
#   Ingested batch 931 of 2387
#   Ingested batch 932 of 2387
#   Ingested batch 933 of 2387
#   Ingested batch 934 of 2387
#   Ingested batch 935 of 2387
#   Ingested batch 936 of 2387
#   Ingested batch 937 of 2387
#   Ingested batch 938 of 2387
#   Ingested batch 939 of 2387
#   Ingested batch 940 of 2387
#   Ingested batch 941 of 2387
#   Ingested batch 942 of 2387
#   Ingested batch 943 of 2387
#   Ingested batch 944 of 2387
#   Ingested batch 945 of 2387
#   Ingested batch 946 of 2387
#   Ingested batch 947 of 2387
#   Ingested batch 948 of 2387
#   Ingested batch 949 of 2387
#   Ingested batch 950 of 2387
#   Ingested batch 951 of 2387
#   Ingested batch 952 of 2387
#   Ingested batch 953 of 2387
#   Ingested batch 954 of 2387
#   Ingested batch 955 of 2387
#   Ingested batch 956 of 2387
#   Ingested batch 957 of 2387
#   Ingested batch 958 of 2387
#   Ingested batch 959 of 2387
#   Ingested batch 960 of 2387
#   Ingested batch 961 of 2387
#   Ingested batch 962 of 2387
#   Ingested batch 963 of 2387
#   Ingested batch 964 of 2387
#   Ingested batch 965 of 2387
#   Ingested batch 966 of 2387
#   Ingested batch 967 of 2387
#   Ingested batch 968 of 2387
#   Ingested batch 969 of 2387
#   Ingested batch 970 of 2387
#   Ingested batch 971 of 2387
#   Ingested batch 972 of 2387
#   Ingested batch 973 of 2387
#   Ingested batch 974 of 2387
#   Ingested batch 975 of 2387
#   Ingested batch 976 of 2387
#   Ingested batch 977 of 2387
#   Ingested batch 978 of 2387
#   Ingested batch 979 of 2387
#   Ingested batch 980 of 2387
#   Ingested batch 981 of 2387
#   Ingested batch 982 of 2387
#   Ingested batch 983 of 2387
#   Ingested batch 984 of 2387
#   Ingested batch 985 of 2387
#   Ingested batch 986 of 2387
#   Ingested batch 987 of 2387
#   Ingested batch 988 of 2387
#   Ingested batch 989 of 2387
#   Ingested batch 990 of 2387
#   Ingested batch 991 of 2387
#   Ingested batch 992 of 2387
#   Ingested batch 993 of 2387
#   Ingested batch 994 of 2387
#   Ingested batch 995 of 2387
#   Ingested batch 996 of 2387
#   Ingested batch 997 of 2387
#   Ingested batch 998 of 2387
#   Ingested batch 999 of 2387
#   Ingested batch 1000 of 2387
#   Ingested batch 1001 of 2387
#   Ingested batch 1002 of 2387
#   Ingested batch 1003 of 2387
#   Ingested batch 1004 of 2387
#   Ingested batch 1005 of 2387
#   Ingested batch 1006 of 2387
#   Ingested batch 1007 of 2387
#   Ingested batch 1008 of 2387
#   Ingested batch 1009 of 2387
#   Ingested batch 1010 of 2387
#   Ingested batch 1011 of 2387
#   Ingested batch 1012 of 2387
#   Ingested batch 1013 of 2387
#   Ingested batch 1014 of 2387
#   Ingested batch 1015 of 2387
#   Ingested batch 1016 of 2387
#   Ingested batch 1017 of 2387
#   Ingested batch 1018 of 2387
#   Ingested batch 1019 of 2387
#   Ingested batch 1020 of 2387
#   Ingested batch 1021 of 2387
#   Ingested batch 1022 of 2387
#   Ingested batch 1023 of 2387
#   Ingested batch 1024 of 2387
#   Ingested batch 1025 of 2387
#   Ingested batch 1026 of 2387
#   Ingested batch 1027 of 2387
#   Ingested batch 1028 of 2387
#   Ingested batch 1029 of 2387
#   Ingested batch 1030 of 2387
#   Ingested batch 1031 of 2387
#   Ingested batch 1032 of 2387
#   Ingested batch 1033 of 2387
#   Ingested batch 1034 of 2387
#   Ingested batch 1035 of 2387
#   Ingested batch 1036 of 2387
#   Ingested batch 1037 of 2387
#   Ingested batch 1038 of 2387
#   Ingested batch 1039 of 2387
#   Ingested batch 1040 of 2387
#   Ingested batch 1041 of 2387
#   Ingested batch 1042 of 2387
#   Ingested batch 1043 of 2387
#   Ingested batch 1044 of 2387
#   Ingested batch 1045 of 2387
#   Ingested batch 1046 of 2387
#   Ingested batch 1047 of 2387
#   Ingested batch 1048 of 2387
#   Ingested batch 1049 of 2387
#   Ingested batch 1050 of 2387
#   Ingested batch 1051 of 2387
#   Ingested batch 1052 of 2387
#   Ingested batch 1053 of 2387
#   Ingested batch 1054 of 2387
#   Ingested batch 1055 of 2387
#   Ingested batch 1056 of 2387
#   Ingested batch 1057 of 2387
#   Ingested batch 1058 of 2387
#   Ingested batch 1059 of 2387
#   Ingested batch 1060 of 2387
#   Ingested batch 1061 of 2387
#   Ingested batch 1062 of 2387
#   Ingested batch 1063 of 2387
#   Ingested batch 1064 of 2387
#   Ingested batch 1065 of 2387
#   Ingested batch 1066 of 2387
#   Ingested batch 1067 of 2387
#   Ingested batch 1068 of 2387
#   Ingested batch 1069 of 2387
#   Ingested batch 1070 of 2387
#   Ingested batch 1071 of 2387
#   Ingested batch 1072 of 2387
#   Ingested batch 1073 of 2387
#   Ingested batch 1074 of 2387
#   Ingested batch 1075 of 2387
#   Ingested batch 1076 of 2387
#   Ingested batch 1077 of 2387
#   Ingested batch 1078 of 2387
#   Ingested batch 1079 of 2387
#   Ingested batch 1080 of 2387
#   Ingested batch 1081 of 2387
#   Ingested batch 1082 of 2387
#   Ingested batch 1083 of 2387
#   Ingested batch 1084 of 2387
#   Ingested batch 1085 of 2387
#   Ingested batch 1086 of 2387
#   Ingested batch 1087 of 2387
#   Ingested batch 1088 of 2387
#   Ingested batch 1089 of 2387
#   Ingested batch 1090 of 2387
#   Ingested batch 1091 of 2387
#   Ingested batch 1092 of 2387
#   Ingested batch 1093 of 2387
#   Ingested batch 1094 of 2387
#   Ingested batch 1095 of 2387
#   Ingested batch 1096 of 2387
#   Ingested batch 1097 of 2387
#   Ingested batch 1098 of 2387
#   Ingested batch 1099 of 2387
#   Ingested batch 1100 of 2387
#   Ingested batch 1101 of 2387
#   Ingested batch 1102 of 2387
#   Ingested batch 1103 of 2387
#   Ingested batch 1104 of 2387
#   Ingested batch 1105 of 2387
#   Ingested batch 1106 of 2387
#   Ingested batch 1107 of 2387
#   Ingested batch 1108 of 2387
#   Ingested batch 1109 of 2387
#   Ingested batch 1110 of 2387
#   Ingested batch 1111 of 2387
#   Ingested batch 1112 of 2387
#   Ingested batch 1113 of 2387
#   Ingested batch 1114 of 2387
#   Ingested batch 1115 of 2387
#   Ingested batch 1116 of 2387
#   Ingested batch 1117 of 2387
#   Ingested batch 1118 of 2387
#   Ingested batch 1119 of 2387
#   Ingested batch 1120 of 2387
#   Ingested batch 1121 of 2387
#   Ingested batch 1122 of 2387
#   Ingested batch 1123 of 2387
#   Ingested batch 1124 of 2387
#   Ingested batch 1125 of 2387
#   Ingested batch 1126 of 2387
#   Ingested batch 1127 of 2387
#   Ingested batch 1128 of 2387
#   Ingested batch 1129 of 2387
#   Ingested batch 1130 of 2387
#   Ingested batch 1131 of 2387
#   Ingested batch 1132 of 2387
#   Ingested batch 1133 of 2387
#   Ingested batch 1134 of 2387
#   Ingested batch 1135 of 2387
#   Ingested batch 1136 of 2387
#   Ingested batch 1137 of 2387
#   Ingested batch 1138 of 2387
#   Ingested batch 1139 of 2387
#   Ingested batch 1140 of 2387
#   Ingested batch 1141 of 2387
#   Ingested batch 1142 of 2387
#   Ingested batch 1143 of 2387
#   Ingested batch 1144 of 2387
#   Ingested batch 1145 of 2387
#   Ingested batch 1146 of 2387
#   Ingested batch 1147 of 2387
#   Ingested batch 1148 of 2387
#   Ingested batch 1149 of 2387
#   Ingested batch 1150 of 2387
#   Ingested batch 1151 of 2387
#   Ingested batch 1152 of 2387
#   Ingested batch 1153 of 2387
#   Ingested batch 1154 of 2387
#   Ingested batch 1155 of 2387
#   Ingested batch 1156 of 2387
#   Ingested batch 1157 of 2387
#   Ingested batch 1158 of 2387
#   Ingested batch 1159 of 2387
#   Ingested batch 1160 of 2387
#   Ingested batch 1161 of 2387
#   Ingested batch 1162 of 2387
#   Ingested batch 1163 of 2387
#   Ingested batch 1164 of 2387
#   Ingested batch 1165 of 2387
#   Ingested batch 1166 of 2387
#   Ingested batch 1167 of 2387
#   Ingested batch 1168 of 2387
#   Ingested batch 1169 of 2387
#   Ingested batch 1170 of 2387
#   Ingested batch 1171 of 2387
#   Ingested batch 1172 of 2387
#   Ingested batch 1173 of 2387
#   Ingested batch 1174 of 2387
#   Ingested batch 1175 of 2387
#   Ingested batch 1176 of 2387
#   Ingested batch 1177 of 2387
#   Ingested batch 1178 of 2387
#   Ingested batch 1179 of 2387
#   Ingested batch 1180 of 2387
#   Ingested batch 1181 of 2387
#   Ingested batch 1182 of 2387
#   Ingested batch 1183 of 2387
#   Ingested batch 1184 of 2387
#   Ingested batch 1185 of 2387
#   Ingested batch 1186 of 2387
#   Ingested batch 1187 of 2387
#   Ingested batch 1188 of 2387
#   Ingested batch 1189 of 2387
#   Ingested batch 1190 of 2387
#   Ingested batch 1191 of 2387
#   Ingested batch 1192 of 2387
#   Ingested batch 1193 of 2387
#   Ingested batch 1194 of 2387
#   Ingested batch 1195 of 2387
#   Ingested batch 1196 of 2387
#   Ingested batch 1197 of 2387
#   Ingested batch 1198 of 2387
#   Ingested batch 1199 of 2387
#   Ingested batch 1200 of 2387
#   Ingested batch 1201 of 2387
#   Ingested batch 1202 of 2387
#   Ingested batch 1203 of 2387
#   Ingested batch 1204 of 2387
#   Ingested batch 1205 of 2387
#   Ingested batch 1206 of 2387
#   Ingested batch 1207 of 2387
#   Ingested batch 1208 of 2387
#   Ingested batch 1209 of 2387
#   Ingested batch 1210 of 2387
#   Ingested batch 1211 of 2387
#   Ingested batch 1212 of 2387
#   Ingested batch 1213 of 2387
#   Ingested batch 1214 of 2387
#   Ingested batch 1215 of 2387
#   Ingested batch 1216 of 2387
#   Ingested batch 1217 of 2387
#   Ingested batch 1218 of 2387
#   Ingested batch 1219 of 2387
#   Ingested batch 1220 of 2387
#   Ingested batch 1221 of 2387
#   Ingested batch 1222 of 2387
#   Ingested batch 1223 of 2387
#   Ingested batch 1224 of 2387
#   Ingested batch 1225 of 2387
#   Ingested batch 1226 of 2387
#   Ingested batch 1227 of 2387
#   Ingested batch 1228 of 2387
#   Ingested batch 1229 of 2387
#   Ingested batch 1230 of 2387
#   Ingested batch 1231 of 2387
#   Ingested batch 1232 of 2387
#   Ingested batch 1233 of 2387
#   Ingested batch 1234 of 2387
#   Ingested batch 1235 of 2387
#   Ingested batch 1236 of 2387
#   Ingested batch 1237 of 2387
#   Ingested batch 1238 of 2387
#   Ingested batch 1239 of 2387
#   Ingested batch 1240 of 2387
#   Ingested batch 1241 of 2387
#   Ingested batch 1242 of 2387
#   Ingested batch 1243 of 2387
#   Ingested batch 1244 of 2387
#   Ingested batch 1245 of 2387
#   Ingested batch 1246 of 2387
#   Ingested batch 1247 of 2387
#   Ingested batch 1248 of 2387
#   Ingested batch 1249 of 2387
#   Ingested batch 1250 of 2387
#   Ingested batch 1251 of 2387
#   Ingested batch 1252 of 2387
#   Ingested batch 1253 of 2387
#   Ingested batch 1254 of 2387
#   Ingested batch 1255 of 2387
#   Ingested batch 1256 of 2387
#   Ingested batch 1257 of 2387
#   Ingested batch 1258 of 2387
#   Ingested batch 1259 of 2387
#   Ingested batch 1260 of 2387
#   Ingested batch 1261 of 2387
#   Ingested batch 1262 of 2387
#   Ingested batch 1263 of 2387
#   Ingested batch 1264 of 2387
#   Ingested batch 1265 of 2387
#   Ingested batch 1266 of 2387
#   Ingested batch 1267 of 2387
#   Ingested batch 1268 of 2387
#   Ingested batch 1269 of 2387
#   Ingested batch 1270 of 2387
#   Ingested batch 1271 of 2387
#   Ingested batch 1272 of 2387
#   Ingested batch 1273 of 2387
#   Ingested batch 1274 of 2387
#   Ingested batch 1275 of 2387
#   Ingested batch 1276 of 2387
#   Ingested batch 1277 of 2387
#   Ingested batch 1278 of 2387
#   Ingested batch 1279 of 2387
#   Ingested batch 1280 of 2387
#   Ingested batch 1281 of 2387
#   Ingested batch 1282 of 2387
#   Ingested batch 1283 of 2387
#   Ingested batch 1284 of 2387
#   Ingested batch 1285 of 2387
#   Ingested batch 1286 of 2387
#   Ingested batch 1287 of 2387
#   Ingested batch 1288 of 2387
#   Ingested batch 1289 of 2387
#   Ingested batch 1290 of 2387
#   Ingested batch 1291 of 2387
#   Ingested batch 1292 of 2387
#   Ingested batch 1293 of 2387
#   Ingested batch 1294 of 2387
#   Ingested batch 1295 of 2387
#   Ingested batch 1296 of 2387
#   Ingested batch 1297 of 2387
#   Ingested batch 1298 of 2387
#   Ingested batch 1299 of 2387
#   Ingested batch 1300 of 2387
#   Ingested batch 1301 of 2387
#   Ingested batch 1302 of 2387
#   Ingested batch 1303 of 2387
#   Ingested batch 1304 of 2387
#   Ingested batch 1305 of 2387
#   Ingested batch 1306 of 2387
#   Ingested batch 1307 of 2387
#   Ingested batch 1308 of 2387
#   Ingested batch 1309 of 2387
#   Ingested batch 1310 of 2387
#   Ingested batch 1311 of 2387
#   Ingested batch 1312 of 2387
#   Ingested batch 1313 of 2387
#   Ingested batch 1314 of 2387
#   Ingested batch 1315 of 2387
#   Ingested batch 1316 of 2387
#   Ingested batch 1317 of 2387
#   Ingested batch 1318 of 2387
#   Ingested batch 1319 of 2387
#   Ingested batch 1320 of 2387
#   Ingested batch 1321 of 2387
#   Ingested batch 1322 of 2387
#   Ingested batch 1323 of 2387
#   Ingested batch 1324 of 2387
#   Ingested batch 1325 of 2387
#   Ingested batch 1326 of 2387
#   Ingested batch 1327 of 2387
#   Ingested batch 1328 of 2387
#   Ingested batch 1329 of 2387
#   Ingested batch 1330 of 2387
#   Ingested batch 1331 of 2387
#   Ingested batch 1332 of 2387
#   Ingested batch 1333 of 2387
#   Ingested batch 1334 of 2387
#   Ingested batch 1335 of 2387
#   Ingested batch 1336 of 2387
#   Ingested batch 1337 of 2387
#   Ingested batch 1338 of 2387
#   Ingested batch 1339 of 2387
#   Ingested batch 1340 of 2387
#   Ingested batch 1341 of 2387
#   Ingested batch 1342 of 2387
#   Ingested batch 1343 of 2387
#   Ingested batch 1344 of 2387
#   Ingested batch 1345 of 2387
#   Ingested batch 1346 of 2387
#   Ingested batch 1347 of 2387
#   Ingested batch 1348 of 2387
#   Ingested batch 1349 of 2387
#   Ingested batch 1350 of 2387
#   Ingested batch 1351 of 2387
#   Ingested batch 1352 of 2387
#   Ingested batch 1353 of 2387
#   Ingested batch 1354 of 2387
#   Ingested batch 1355 of 2387
#   Ingested batch 1356 of 2387
#   Ingested batch 1357 of 2387
#   Ingested batch 1358 of 2387
#   Ingested batch 1359 of 2387
#   Ingested batch 1360 of 2387
#   Ingested batch 1361 of 2387
#   Ingested batch 1362 of 2387
#   Ingested batch 1363 of 2387
#   Ingested batch 1364 of 2387
#   Ingested batch 1365 of 2387
#   Ingested batch 1366 of 2387
#   Ingested batch 1367 of 2387
#   Ingested batch 1368 of 2387
#   Ingested batch 1369 of 2387
#   Ingested batch 1370 of 2387
#   Ingested batch 1371 of 2387
#   Ingested batch 1372 of 2387
#   Ingested batch 1373 of 2387
#   Ingested batch 1374 of 2387
#   Ingested batch 1375 of 2387
#   Ingested batch 1376 of 2387
#   Ingested batch 1377 of 2387
#   Ingested batch 1378 of 2387
#   Ingested batch 1379 of 2387
#   Ingested batch 1380 of 2387
#   Ingested batch 1381 of 2387
#   Ingested batch 1382 of 2387
#   Ingested batch 1383 of 2387
#   Ingested batch 1384 of 2387
#   Ingested batch 1385 of 2387
#   Ingested batch 1386 of 2387
#   Ingested batch 1387 of 2387
#   Ingested batch 1388 of 2387
#   Ingested batch 1389 of 2387
#   Ingested batch 1390 of 2387
#   Ingested batch 1391 of 2387
#   Ingested batch 1392 of 2387
#   Ingested batch 1393 of 2387
#   Ingested batch 1394 of 2387
#   Ingested batch 1395 of 2387
#   Ingested batch 1396 of 2387
#   Ingested batch 1397 of 2387
#   Ingested batch 1398 of 2387
#   Ingested batch 1399 of 2387
#   Ingested batch 1400 of 2387
#   Ingested batch 1401 of 2387
#   Ingested batch 1402 of 2387
#   Ingested batch 1403 of 2387
#   Ingested batch 1404 of 2387
#   Ingested batch 1405 of 2387
#   Ingested batch 1406 of 2387
#   Ingested batch 1407 of 2387
#   Ingested batch 1408 of 2387
#   Ingested batch 1409 of 2387
#   Ingested batch 1410 of 2387
#   Ingested batch 1411 of 2387
#   Ingested batch 1412 of 2387
#   Ingested batch 1413 of 2387
#   Ingested batch 1414 of 2387
#   Ingested batch 1415 of 2387
#   Ingested batch 1416 of 2387
#   Ingested batch 1417 of 2387
#   Ingested batch 1418 of 2387
#   Ingested batch 1419 of 2387
#   Ingested batch 1420 of 2387
#   Ingested batch 1421 of 2387
#   Ingested batch 1422 of 2387
#   Ingested batch 1423 of 2387
#   Ingested batch 1424 of 2387
#   Ingested batch 1425 of 2387
#   Ingested batch 1426 of 2387
#   Ingested batch 1427 of 2387
#   Ingested batch 1428 of 2387
#   Ingested batch 1429 of 2387
#   Ingested batch 1430 of 2387
#   Ingested batch 1431 of 2387
#   Ingested batch 1432 of 2387
#   Ingested batch 1433 of 2387
#   Ingested batch 1434 of 2387
#   Ingested batch 1435 of 2387
#   Ingested batch 1436 of 2387
#   Ingested batch 1437 of 2387
#   Ingested batch 1438 of 2387
#   Ingested batch 1439 of 2387
#   Ingested batch 1440 of 2387
#   Ingested batch 1441 of 2387
#   Ingested batch 1442 of 2387
#   Ingested batch 1443 of 2387
#   Ingested batch 1444 of 2387
#   Ingested batch 1445 of 2387
#   Ingested batch 1446 of 2387
#   Ingested batch 1447 of 2387
#   Ingested batch 1448 of 2387
#   Ingested batch 1449 of 2387
#   Ingested batch 1450 of 2387
#   Ingested batch 1451 of 2387
#   Ingested batch 1452 of 2387
#   Ingested batch 1453 of 2387
#   Ingested batch 1454 of 2387
#   Ingested batch 1455 of 2387
#   Ingested batch 1456 of 2387
#   Ingested batch 1457 of 2387
#   Ingested batch 1458 of 2387
#   Ingested batch 1459 of 2387
#   Ingested batch 1460 of 2387
#   Ingested batch 1461 of 2387
#   Ingested batch 1462 of 2387
#   Ingested batch 1463 of 2387
#   Ingested batch 1464 of 2387
#   Ingested batch 1465 of 2387
#   Ingested batch 1466 of 2387
#   Ingested batch 1467 of 2387
#   Ingested batch 1468 of 2387
#   Ingested batch 1469 of 2387
#   Ingested batch 1470 of 2387
#   Ingested batch 1471 of 2387
#   Ingested batch 1472 of 2387
#   Ingested batch 1473 of 2387
#   Ingested batch 1474 of 2387
#   Ingested batch 1475 of 2387
#   Ingested batch 1476 of 2387
#   Ingested batch 1477 of 2387
#   Ingested batch 1478 of 2387
#   Ingested batch 1479 of 2387
#   Ingested batch 1480 of 2387
#   Ingested batch 1481 of 2387
#   Ingested batch 1482 of 2387
#   Ingested batch 1483 of 2387
#   Ingested batch 1484 of 2387
#   Ingested batch 1485 of 2387
#   Ingested batch 1486 of 2387
#   Ingested batch 1487 of 2387
#   Ingested batch 1488 of 2387
#   Ingested batch 1489 of 2387
#   Ingested batch 1490 of 2387
#   Ingested batch 1491 of 2387
#   Ingested batch 1492 of 2387
#   Ingested batch 1493 of 2387
#   Ingested batch 1494 of 2387
#   Ingested batch 1495 of 2387
#   Ingested batch 1496 of 2387
#   Ingested batch 1497 of 2387
#   Ingested batch 1498 of 2387
#   Ingested batch 1499 of 2387
#   Ingested batch 1500 of 2387
#   Ingested batch 1501 of 2387
#   Ingested batch 1502 of 2387
#   Ingested batch 1503 of 2387
#   Ingested batch 1504 of 2387
#   Ingested batch 1505 of 2387
#   Ingested batch 1506 of 2387
#   Ingested batch 1507 of 2387
#   Ingested batch 1508 of 2387
#   Ingested batch 1509 of 2387
#   Ingested batch 1510 of 2387
#   Ingested batch 1511 of 2387
#   Ingested batch 1512 of 2387
#   Ingested batch 1513 of 2387
#   Ingested batch 1514 of 2387
#   Ingested batch 1515 of 2387
#   Ingested batch 1516 of 2387
#   Ingested batch 1517 of 2387
#   Ingested batch 1518 of 2387
#   Ingested batch 1519 of 2387
#   Ingested batch 1520 of 2387
#   Ingested batch 1521 of 2387
#   Ingested batch 1522 of 2387
#   Ingested batch 1523 of 2387
#   Ingested batch 1524 of 2387
#   Ingested batch 1525 of 2387
#   Ingested batch 1526 of 2387
#   Ingested batch 1527 of 2387
#   Ingested batch 1528 of 2387
#   Ingested batch 1529 of 2387
#   Ingested batch 1530 of 2387
#   Ingested batch 1531 of 2387
#   Ingested batch 1532 of 2387
#   Ingested batch 1533 of 2387
#   Ingested batch 1534 of 2387
#   Ingested batch 1535 of 2387
#   Ingested batch 1536 of 2387
#   Ingested batch 1537 of 2387
#   Ingested batch 1538 of 2387
#   Ingested batch 1539 of 2387
#   Ingested batch 1540 of 2387
#   Ingested batch 1541 of 2387
#   Ingested batch 1542 of 2387
#   Ingested batch 1543 of 2387
#   Ingested batch 1544 of 2387
#   Ingested batch 1545 of 2387
#   Ingested batch 1546 of 2387
#   Ingested batch 1547 of 2387
#   Ingested batch 1548 of 2387
#   Ingested batch 1549 of 2387
#   Ingested batch 1550 of 2387
#   Ingested batch 1551 of 2387
#   Ingested batch 1552 of 2387
#   Ingested batch 1553 of 2387
#   Ingested batch 1554 of 2387
#   Ingested batch 1555 of 2387
#   Ingested batch 1556 of 2387
#   Ingested batch 1557 of 2387
#   Ingested batch 1558 of 2387
#   Ingested batch 1559 of 2387
#   Ingested batch 1560 of 2387
#   Ingested batch 1561 of 2387
#   Ingested batch 1562 of 2387
#   Ingested batch 1563 of 2387
#   Ingested batch 1564 of 2387
#   Ingested batch 1565 of 2387
#   Ingested batch 1566 of 2387
#   Ingested batch 1567 of 2387
#   Ingested batch 1568 of 2387
#   Ingested batch 1569 of 2387
#   Ingested batch 1570 of 2387
#   Ingested batch 1571 of 2387
#   Ingested batch 1572 of 2387
#   Ingested batch 1573 of 2387
#   Ingested batch 1574 of 2387
#   Ingested batch 1575 of 2387
#   Ingested batch 1576 of 2387
#   Ingested batch 1577 of 2387
#   Ingested batch 1578 of 2387
#   Ingested batch 1579 of 2387
#   Ingested batch 1580 of 2387
#   Ingested batch 1581 of 2387
#   Ingested batch 1582 of 2387
#   Ingested batch 1583 of 2387
#   Ingested batch 1584 of 2387
#   Ingested batch 1585 of 2387
#   Ingested batch 1586 of 2387
#   Ingested batch 1587 of 2387
#   Ingested batch 1588 of 2387
#   Ingested batch 1589 of 2387
#   Ingested batch 1590 of 2387
#   Ingested batch 1591 of 2387
#   Ingested batch 1592 of 2387
#   Ingested batch 1593 of 2387
#   Ingested batch 1594 of 2387
#   Ingested batch 1595 of 2387
#   Ingested batch 1596 of 2387
#   Ingested batch 1597 of 2387
#   Ingested batch 1598 of 2387
#   Ingested batch 1599 of 2387
#   Ingested batch 1600 of 2387
#   Ingested batch 1601 of 2387
#   Ingested batch 1602 of 2387
#   Ingested batch 1603 of 2387
#   Ingested batch 1604 of 2387
#   Ingested batch 1605 of 2387
#   Ingested batch 1606 of 2387
#   Ingested batch 1607 of 2387
#   Ingested batch 1608 of 2387
#   Ingested batch 1609 of 2387
#   Ingested batch 1610 of 2387
#   Ingested batch 1611 of 2387
#   Ingested batch 1612 of 2387
#   Ingested batch 1613 of 2387
#   Ingested batch 1614 of 2387
#   Ingested batch 1615 of 2387
#   Ingested batch 1616 of 2387
#   Ingested batch 1617 of 2387
#   Ingested batch 1618 of 2387
#   Ingested batch 1619 of 2387
#   Ingested batch 1620 of 2387
#   Ingested batch 1621 of 2387
#   Ingested batch 1622 of 2387
#   Ingested batch 1623 of 2387
#   Ingested batch 1624 of 2387
# ...
#   Ingested batch 1858 of 2387
#   Ingested batch 1859 of 2387
#   Ingested batch 1860 of 2387
#   Ingested batch 1861 of 2387
#   Ingested batch 1862 of 2387
#   Ingested batch 1863 of 2387
#   Ingested batch 1864 of 2387
#   Ingested batch 1865 of 2387
#   Ingested batch 1866 of 2387
#   Ingested batch 1867 of 2387
#   Ingested batch 1868 of 2387
#   Ingested batch 1869 of 2387
#   Ingested batch 1870 of 2387
#   Ingested batch 1871 of 2387
#   Ingested batch 1872 of 2387
#   Ingested batch 1873 of 2387
#   Ingested batch 1874 of 2387
#   Ingested batch 1875 of 2387
#   Ingested batch 1876 of 2387
#   Ingested batch 1877 of 2387
#   Ingested batch 1878 of 2387
#   Ingested batch 1879 of 2387
#   Ingested batch 1880 of 2387
#   Ingested batch 1881 of 2387
#   Ingested batch 1882 of 2387
#   Ingested batch 1883 of 2387
#   Ingested batch 1884 of 2387
#   Ingested batch 1885 of 2387
#   Ingested batch 1886 of 2387
#   Ingested batch 1887 of 2387
#   Ingested batch 1888 of 2387
#   Ingested batch 1889 of 2387
#   Ingested batch 1890 of 2387
#   Ingested batch 1891 of 2387
#   Ingested batch 1892 of 2387
#   Ingested batch 1893 of 2387
#   Ingested batch 1894 of 2387
#   Ingested batch 1895 of 2387
#   Ingested batch 1896 of 2387
#   Ingested batch 1897 of 2387
#   Ingested batch 1898 of 2387
#   Ingested batch 1899 of 2387
#   Ingested batch 1900 of 2387
#   Ingested batch 1901 of 2387
#   Ingested batch 1902 of 2387
#   Ingested batch 1903 of 2387
#   Ingested batch 1904 of 2387
#   Ingested batch 1905 of 2387
#   Ingested batch 1906 of 2387
#   Ingested batch 1907 of 2387
#   Ingested batch 1908 of 2387
#   Ingested batch 1909 of 2387
#   Ingested batch 1910 of 2387
#   Ingested batch 1911 of 2387
#   Ingested batch 1912 of 2387
#   Ingested batch 1913 of 2387
#   Ingested batch 1914 of 2387
#   Ingested batch 1915 of 2387
#   Ingested batch 1916 of 2387
#   Ingested batch 1917 of 2387
#   Ingested batch 1918 of 2387
#   Ingested batch 1919 of 2387
#   Ingested batch 1920 of 2387
#   Ingested batch 1921 of 2387
#   Ingested batch 1922 of 2387
#   Ingested batch 1923 of 2387
#   Ingested batch 1924 of 2387
#   Ingested batch 1925 of 2387
#   Ingested batch 1926 of 2387
#   Ingested batch 1927 of 2387
#   Ingested batch 1928 of 2387
#   Ingested batch 1929 of 2387
#   Ingested batch 1930 of 2387
#   Ingested batch 1931 of 2387
#   Ingested batch 1932 of 2387
#   Ingested batch 1933 of 2387
#   Ingested batch 1934 of 2387
#   Ingested batch 1935 of 2387
#   Ingested batch 1936 of 2387
#   Ingested batch 1937 of 2387
#   Ingested batch 1938 of 2387
#   Ingested batch 1939 of 2387
#   Ingested batch 1940 of 2387
#   Ingested batch 1941 of 2387
#   Ingested batch 1942 of 2387
#   Ingested batch 1943 of 2387
#   Ingested batch 1944 of 2387
#   Ingested batch 1945 of 2387
#   Ingested batch 1946 of 2387
#   Ingested batch 1947 of 2387
#   Ingested batch 1948 of 2387
#   Ingested batch 1949 of 2387
#   Ingested batch 1950 of 2387
#   Ingested batch 1951 of 2387
#   Ingested batch 1952 of 2387
#   Ingested batch 1953 of 2387
#   Ingested batch 1954 of 2387
#   Ingested batch 1955 of 2387
#   Ingested batch 1956 of 2387
#   Ingested batch 1957 of 2387
#   Ingested batch 1958 of 2387
#   Ingested batch 1959 of 2387
#   Ingested batch 1960 of 2387
#   Ingested batch 1961 of 2387
#   Ingested batch 1962 of 2387
#   Ingested batch 1963 of 2387
#   Ingested batch 1964 of 2387
#   Ingested batch 1965 of 2387
#   Ingested batch 1966 of 2387
#   Ingested batch 1967 of 2387
#   Ingested batch 1968 of 2387
#   Ingested batch 1969 of 2387
#   Ingested batch 1970 of 2387
#   Ingested batch 1971 of 2387
#   Ingested batch 1972 of 2387
#   Ingested batch 1973 of 2387
#   Ingested batch 1974 of 2387
#   Ingested batch 1975 of 2387
#   Ingested batch 1976 of 2387
#   Ingested batch 1977 of 2387
#   Ingested batch 1978 of 2387
#   Ingested batch 1979 of 2387
#   Ingested batch 1980 of 2387
#   Ingested batch 1981 of 2387
#   Ingested batch 1982 of 2387
#   Ingested batch 1983 of 2387
#   Ingested batch 1984 of 2387
#   Ingested batch 1985 of 2387
#   Ingested batch 1986 of 2387
#   Ingested batch 1987 of 2387
#   Ingested batch 1988 of 2387
#   Ingested batch 1989 of 2387
#   Ingested batch 1990 of 2387
#   Ingested batch 1991 of 2387
#   Ingested batch 1992 of 2387
#   Ingested batch 1993 of 2387
#   Ingested batch 1994 of 2387
#   Ingested batch 1995 of 2387
#   Ingested batch 1996 of 2387
#   Ingested batch 1997 of 2387
#   Ingested batch 1998 of 2387
#   Ingested batch 1999 of 2387
#   Ingested batch 2000 of 2387
#   Ingested batch 2001 of 2387
#   Ingested batch 2002 of 2387
#   Ingested batch 2003 of 2387
#   Ingested batch 2004 of 2387
#   Ingested batch 2005 of 2387
#   Ingested batch 2006 of 2387
#   Ingested batch 2007 of 2387
#   Ingested batch 2008 of 2387
#   Ingested batch 2009 of 2387
#   Ingested batch 2010 of 2387
#   Ingested batch 2011 of 2387
#   Ingested batch 2012 of 2387
#   Ingested batch 2013 of 2387
#   Ingested batch 2014 of 2387
#   Ingested batch 2015 of 2387
#   Ingested batch 2016 of 2387
#   Ingested batch 2017 of 2387
#   Ingested batch 2018 of 2387
#   Ingested batch 2019 of 2387
#   Ingested batch 2020 of 2387
#   Ingested batch 2021 of 2387
#   Ingested batch 2022 of 2387
#   Ingested batch 2023 of 2387
#   Ingested batch 2024 of 2387
#   Ingested batch 2025 of 2387
#   Ingested batch 2026 of 2387
#   Ingested batch 2027 of 2387
#   Ingested batch 2028 of 2387
#   Ingested batch 2029 of 2387
#   Ingested batch 2030 of 2387
#   Ingested batch 2031 of 2387
#   Ingested batch 2032 of 2387
#   Ingested batch 2033 of 2387
#   Ingested batch 2034 of 2387
#   Ingested batch 2035 of 2387
#   Ingested batch 2036 of 2387
#   Ingested batch 2037 of 2387
#   Ingested batch 2038 of 2387
#   Ingested batch 2039 of 2387
#   Ingested batch 2040 of 2387
#   Ingested batch 2041 of 2387
#   Ingested batch 2042 of 2387
#   Ingested batch 2043 of 2387
#   Ingested batch 2044 of 2387
#   Ingested batch 2045 of 2387
#   Ingested batch 2046 of 2387
#   Ingested batch 2047 of 2387
#   Ingested batch 2048 of 2387
#   Ingested batch 2049 of 2387
#   Ingested batch 2050 of 2387
#   Ingested batch 2051 of 2387
#   Ingested batch 2052 of 2387
#   Ingested batch 2053 of 2387
#   Ingested batch 2054 of 2387
#   Ingested batch 2055 of 2387
#   Ingested batch 2056 of 2387
#   Ingested batch 2057 of 2387
#   Ingested batch 2058 of 2387
#   Ingested batch 2059 of 2387
#   Ingested batch 2060 of 2387
#   Ingested batch 2061 of 2387
#   Ingested batch 2062 of 2387
#   Ingested batch 2063 of 2387
#   Ingested batch 2064 of 2387
#   Ingested batch 2065 of 2387
#   Ingested batch 2066 of 2387
#   Ingested batch 2067 of 2387
#   Ingested batch 2068 of 2387
#   Ingested batch 2069 of 2387
#   Ingested batch 2070 of 2387
#   Ingested batch 2071 of 2387
#   Ingested batch 2072 of 2387
#   Ingested batch 2073 of 2387
#   Ingested batch 2074 of 2387
#   Ingested batch 2075 of 2387
#   Ingested batch 2076 of 2387
#   Ingested batch 2077 of 2387
#   Ingested batch 2078 of 2387
#   Ingested batch 2079 of 2387
#   Ingested batch 2080 of 2387
#   Ingested batch 2081 of 2387
#   Ingested batch 2082 of 2387
#   Ingested batch 2083 of 2387
#   Ingested batch 2084 of 2387
#   Ingested batch 2085 of 2387
#   Ingested batch 2086 of 2387
#   Ingested batch 2087 of 2387
#   Ingested batch 2088 of 2387
#   Ingested batch 2089 of 2387
#   Ingested batch 2090 of 2387
#   Ingested batch 2091 of 2387
#   Ingested batch 2092 of 2387
#   Ingested batch 2093 of 2387
#   Ingested batch 2094 of 2387
#   Ingested batch 2095 of 2387
#   Ingested batch 2096 of 2387
#   Ingested batch 2097 of 2387
#   Ingested batch 2098 of 2387
#   Ingested batch 2099 of 2387
#   Ingested batch 2100 of 2387
#   Ingested batch 2101 of 2387
#   Ingested batch 2102 of 2387
#   Ingested batch 2103 of 2387
#   Ingested batch 2104 of 2387
#   Ingested batch 2105 of 2387
#   Ingested batch 2106 of 2387
#   Ingested batch 2107 of 2387
#   Ingested batch 2108 of 2387
#   Ingested batch 2109 of 2387
#   Ingested batch 2110 of 2387
#   Ingested batch 2111 of 2387
#   Ingested batch 2112 of 2387
#   Ingested batch 2113 of 2387
#   Ingested batch 2114 of 2387
#   Ingested batch 2115 of 2387
#   Ingested batch 2116 of 2387
#   Ingested batch 2117 of 2387
#   Ingested batch 2118 of 2387
#   Ingested batch 2119 of 2387
#   Ingested batch 2120 of 2387
#   Ingested batch 2121 of 2387
#   Ingested batch 2122 of 2387
#   Ingested batch 2123 of 2387
#   Ingested batch 2124 of 2387
#   Ingested batch 2125 of 2387
#   Ingested batch 2126 of 2387
#   Ingested batch 2127 of 2387
#   Ingested batch 2128 of 2387
#   Ingested batch 2129 of 2387
#   Ingested batch 2130 of 2387
#   Ingested batch 2131 of 2387
#   Ingested batch 2132 of 2387
#   Ingested batch 2133 of 2387
#   Ingested batch 2134 of 2387
#   Ingested batch 2135 of 2387
#   Ingested batch 2136 of 2387
#   Ingested batch 2137 of 2387
#   Ingested batch 2138 of 2387
#   Ingested batch 2139 of 2387
#   Ingested batch 2140 of 2387
#   Ingested batch 2141 of 2387
#   Ingested batch 2142 of 2387
#   Ingested batch 2143 of 2387
#   Ingested batch 2144 of 2387
#   Ingested batch 2145 of 2387
#   Ingested batch 2146 of 2387
#   Ingested batch 2147 of 2387
#   Ingested batch 2148 of 2387
#   Ingested batch 2149 of 2387
#   Ingested batch 2150 of 2387
#   Ingested batch 2151 of 2387
#   Ingested batch 2152 of 2387
#   Ingested batch 2153 of 2387
#   Ingested batch 2154 of 2387
#   Ingested batch 2155 of 2387
#   Ingested batch 2156 of 2387
#   Ingested batch 2157 of 2387
#   Ingested batch 2158 of 2387
#   Ingested batch 2159 of 2387
#   Ingested batch 2160 of 2387
#   Ingested batch 2161 of 2387
#   Ingested batch 2162 of 2387
#   Ingested batch 2163 of 2387
#   Ingested batch 2164 of 2387
#   Ingested batch 2165 of 2387
#   Ingested batch 2166 of 2387
#   Ingested batch 2167 of 2387
#   Ingested batch 2168 of 2387
#   Ingested batch 2169 of 2387
#   Ingested batch 2170 of 2387
#   Ingested batch 2171 of 2387
#   Ingested batch 2172 of 2387
#   Ingested batch 2173 of 2387
#   Ingested batch 2174 of 2387
#   Ingested batch 2175 of 2387
#   Ingested batch 2176 of 2387
#   Ingested batch 2177 of 2387
#   Ingested batch 2178 of 2387
#   Ingested batch 2179 of 2387
#   Ingested batch 2180 of 2387
#   Ingested batch 2181 of 2387
#   Ingested batch 2182 of 2387
#   Ingested batch 2183 of 2387
#   Ingested batch 2184 of 2387
#   Ingested batch 2185 of 2387
#   Ingested batch 2186 of 2387
#   Ingested batch 2187 of 2387
#   Ingested batch 2188 of 2387
#   Ingested batch 2189 of 2387
#   Ingested batch 2190 of 2387
#   Ingested batch 2191 of 2387
#   Ingested batch 2192 of 2387
#   Ingested batch 2193 of 2387
#   Ingested batch 2194 of 2387
#   Ingested batch 2195 of 2387
#   Ingested batch 2196 of 2387
#   Ingested batch 2197 of 2387
#   Ingested batch 2198 of 2387
#   Ingested batch 2199 of 2387
#   Ingested batch 2200 of 2387
#   Ingested batch 2201 of 2387
#   Ingested batch 2202 of 2387
#   Ingested batch 2203 of 2387
#   Ingested batch 2204 of 2387
#   Ingested batch 2205 of 2387
#   Ingested batch 2206 of 2387
#   Ingested batch 2207 of 2387
#   Ingested batch 2208 of 2387
#   Ingested batch 2209 of 2387
#   Ingested batch 2210 of 2387
#   Ingested batch 2211 of 2387
#   Ingested batch 2212 of 2387
#   Ingested batch 2213 of 2387
#   Ingested batch 2214 of 2387
#   Ingested batch 2215 of 2387
#   Ingested batch 2216 of 2387
#   Ingested batch 2217 of 2387
#   Ingested batch 2218 of 2387
#   Ingested batch 2219 of 2387
#   Ingested batch 2220 of 2387
#   Ingested batch 2221 of 2387
#   Ingested batch 2222 of 2387
#   Ingested batch 2223 of 2387
#   Ingested batch 2224 of 2387
#   Ingested batch 2225 of 2387
#   Ingested batch 2226 of 2387
#   Ingested batch 2227 of 2387
#   Ingested batch 2228 of 2387
#   Ingested batch 2229 of 2387
#   Ingested batch 2230 of 2387
#   Ingested batch 2231 of 2387
#   Ingested batch 2232 of 2387
#   Ingested batch 2233 of 2387
#   Ingested batch 2234 of 2387
#   Ingested batch 2235 of 2387
#   Ingested batch 2236 of 2387
#   Ingested batch 2237 of 2387
#   Ingested batch 2238 of 2387
#   Ingested batch 2239 of 2387
#   Ingested batch 2240 of 2387
#   Ingested batch 2241 of 2387
#   Ingested batch 2242 of 2387
#   Ingested batch 2243 of 2387
#   Ingested batch 2244 of 2387
#   Ingested batch 2245 of 2387
#   Ingested batch 2246 of 2387
#   Ingested batch 2247 of 2387
#   Ingested batch 2248 of 2387
#   Ingested batch 2249 of 2387
#   Ingested batch 2250 of 2387
#   Ingested batch 2251 of 2387
#   Ingested batch 2252 of 2387
#   Ingested batch 2253 of 2387
#   Ingested batch 2254 of 2387
#   Ingested batch 2255 of 2387
#   Ingested batch 2256 of 2387
#   Ingested batch 2257 of 2387
#   Ingested batch 2258 of 2387
#   Ingested batch 2259 of 2387
#   Ingested batch 2260 of 2387
#   Ingested batch 2261 of 2387
#   Ingested batch 2262 of 2387
#   Ingested batch 2263 of 2387
#   Ingested batch 2264 of 2387
#   Ingested batch 2265 of 2387
#   Ingested batch 2266 of 2387
#   Ingested batch 2267 of 2387
#   Ingested batch 2268 of 2387
#   Ingested batch 2269 of 2387
#   Ingested batch 2270 of 2387
#   Ingested batch 2271 of 2387
#   Ingested batch 2272 of 2387
#   Ingested batch 2273 of 2387
#   Ingested batch 2274 of 2387
#   Ingested batch 2275 of 2387
#   Ingested batch 2276 of 2387
#   Ingested batch 2277 of 2387
#   Ingested batch 2278 of 2387
#   Ingested batch 2279 of 2387
#   Ingested batch 2280 of 2387
#   Ingested batch 2281 of 2387
#   Ingested batch 2282 of 2387
#   Ingested batch 2283 of 2387
#   Ingested batch 2284 of 2387
#   Ingested batch 2285 of 2387
#   Ingested batch 2286 of 2387
#   Ingested batch 2287 of 2387
#   Ingested batch 2288 of 2387
#   Ingested batch 2289 of 2387
#   Ingested batch 2290 of 2387
#   Ingested batch 2291 of 2387
#   Ingested batch 2292 of 2387
#   Ingested batch 2293 of 2387
#   Ingested batch 2294 of 2387
#   Ingested batch 2295 of 2387
#   Ingested batch 2296 of 2387
#   Ingested batch 2297 of 2387
#   Ingested batch 2298 of 2387
#   Ingested batch 2299 of 2387
#   Ingested batch 2300 of 2387
#   Ingested batch 2301 of 2387
#   Ingested batch 2302 of 2387
#   Ingested batch 2303 of 2387
#   Ingested batch 2304 of 2387
#   Ingested batch 2305 of 2387
#   Ingested batch 2306 of 2387
#   Ingested batch 2307 of 2387
#   Ingested batch 2308 of 2387
#   Ingested batch 2309 of 2387
#   Ingested batch 2310 of 2387
#   Ingested batch 2311 of 2387
#   Ingested batch 2312 of 2387
#   Ingested batch 2313 of 2387
#   Ingested batch 2314 of 2387
#   Ingested batch 2315 of 2387
#   Ingested batch 2316 of 2387
#   Ingested batch 2317 of 2387
#   Ingested batch 2318 of 2387
#   Ingested batch 2319 of 2387
#   Ingested batch 2320 of 2387
#   Ingested batch 2321 of 2387
#   Ingested batch 2322 of 2387
#   Ingested batch 2323 of 2387
#   Ingested batch 2324 of 2387
#   Ingested batch 2325 of 2387
#   Ingested batch 2326 of 2387
#   Ingested batch 2327 of 2387
#   Ingested batch 2328 of 2387
#   Ingested batch 2329 of 2387
#   Ingested batch 2330 of 2387
#   Ingested batch 2331 of 2387
#   Ingested batch 2332 of 2387
#   Ingested batch 2333 of 2387
#   Ingested batch 2334 of 2387
#   Ingested batch 2335 of 2387
#   Ingested batch 2336 of 2387
#   Ingested batch 2337 of 2387
#   Ingested batch 2338 of 2387
#   Ingested batch 2339 of 2387
#   Ingested batch 2340 of 2387
#   Ingested batch 2341 of 2387
#   Ingested batch 2342 of 2387
#   Ingested batch 2343 of 2387
#   Ingested batch 2344 of 2387
#   Ingested batch 2345 of 2387
#   Ingested batch 2346 of 2387
#   Ingested batch 2347 of 2387
#   Ingested batch 2348 of 2387
#   Ingested batch 2349 of 2387
#   Ingested batch 2350 of 2387
#   Ingested batch 2351 of 2387
#   Ingested batch 2352 of 2387
#   Ingested batch 2353 of 2387
#   Ingested batch 2354 of 2387
#   Ingested batch 2355 of 2387
#   Ingested batch 2356 of 2387
#   Ingested batch 2357 of 2387
#   Ingested batch 2358 of 2387
#   Ingested batch 2359 of 2387
#   Ingested batch 2360 of 2387
#   Ingested batch 2361 of 2387
#   Ingested batch 2362 of 2387
#   Ingested batch 2363 of 2387
#   Ingested batch 2364 of 2387
#   Ingested batch 2365 of 2387
#   Ingested batch 2366 of 2387
#   Ingested batch 2367 of 2387
#   Ingested batch 2368 of 2387
#   Ingested batch 2369 of 2387
#   Ingested batch 2370 of 2387
#   Ingested batch 2371 of 2387
#   Ingested batch 2372 of 2387
#   Ingested batch 2373 of 2387
#   Ingested batch 2374 of 2387
#   Ingested batch 2375 of 2387
#   Ingested batch 2376 of 2387
#   Ingested batch 2377 of 2387
#   Ingested batch 2378 of 2387
#   Ingested batch 2379 of 2387
#   Ingested batch 2380 of 2387
#   Ingested batch 2381 of 2387
#   Ingested batch 2382 of 2387
#   Ingested batch 2383 of 2387
#   Ingested batch 2384 of 2387
#   Ingested batch 2385 of 2387
#   Ingested batch 2386 of 2387
#   Ingested batch 2387 of 2387
# User and Rating ingestion complete.
# --------------------
# Driver connection closed.

# %%
# driver = GraphDatabase.driver(URI, auth=AUTH)

def run_query(query, params=None):
    """Executes a read query and returns the results."""
    with driver.session() as session:
        result = session.run(query, params)
        return [record for record in result]

# --- Test Example 1: Verify an anime and its genres ---
anime_title = "Naruto"
query1 = """
MATCH (a:Anime {title: $title})-[:HAS_GENRE]->(g:Genre)
RETURN a.title, COLLECT(g.name) AS Genres
"""
results1 = run_query(query1, {"title": anime_title})
print(f"--- Test 1: Verify {anime_title} and its genres ---")
if results1:
    record = results1[0]
    print(f"Anime: {record['a.title']}")
    print(f"Genres: {', '.join(record['Genres'])}")
else:
    print(f"No results found for {anime_title}. Check your data or query.")
print("-" * 30)


# --- Test Example 2: Find similar animes by genre (Optimized) ---
target_anime = "Naruto "
query2 = """
MATCH (target:Anime {title: $title})-[:HAS_GENRE]->(g:Genre)<-[:HAS_GENRE]-(similar:Anime)
WHERE target <> similar
RETURN similar.title, g.name AS SharedGenre, similar.rating
ORDER BY similar.rating DESC
LIMIT 5
"""
results2 = run_query(query2, {"title": target_anime})
print(f"--- Test 2: Similar to {target_anime} by genre ---")
if results2:
    for record in results2:
        print(f"Title: {record['similar.title']}, Shared Genre: {record['SharedGenre']}, Rating: {record['similar.rating']}")
else:
    print(f"No similar animes found for {target_anime}.")
print("-" * 30)



# --- Test Example 3: Get average rating for an anime ---
anime_title_rating = "Code Geass: Hangyaku no Lelouch"
query3 = """
MATCH (a:Anime {title: $title})<-[r:RATED]-(u:User)
RETURN a.title, avg(r.score) AS AverageRating, count(u) AS TotalRatings
"""
results3 = run_query(query3, {"title": anime_title_rating})
print(f"--- Test 3: Average rating for {anime_title_rating} ---")
if results3 and results3[0]["TotalRatings"] > 0:
    record = results3[0]
    print(f"Anime: {record['a.title']}")
    print(f"Average Rating: {record['AverageRating']:.2f}")
    print(f"Total Ratings: {record['TotalRatings']}")
else:
    print(f"No ratings found for {anime_title_rating}.")
print("-" * 30)


driver.close()
# Out:
# C:\Users\hanso\AppData\Local\Temp\ipykernel_16768\3811103384.py:5: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# --- Test 1: Verify Naruto and its genres ---
# Anime: Naruto
# Genres: Action, Shounen, Martial Arts, Super Power, Comedy
# ------------------------------
# --- Test 2: Similar to Naruto  by genre ---
# No similar animes found for Naruto .
# ------------------------------
# --- Test 3: Average rating for Code Geass: Hangyaku no Lelouch ---
# Anime: Code Geass: Hangyaku no Lelouch
# Average Rating: 8.93
# Total Ratings: 18205
# ------------------------------
